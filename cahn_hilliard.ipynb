# %%
import os
import math
from time import perf_counter

import numpy as np
import scipy.io
from scipy.optimize import minimize
from scipy.linalg import cholesky, LinAlgError

import torch
import torch.nn as nn
from torch.nn.utils import parameters_to_vector, vector_to_parameters

torch.set_default_dtype(torch.float64)
torch.manual_seed(2)

# Random IC via fixed Fourier coefficients
torch.manual_seed(123)
K = 8
ak = torch.randn(K, dtype=torch.get_default_dtype()) * 0.2
bk = torch.randn(K, dtype=torch.get_default_dtype()) * 0.2

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

RESULTS_DIR = "results2"
os.makedirs(RESULTS_DIR, exist_ok=True)

# %%
scaling = 1
L1 = 20
layer_dims = (2, L1, L1, L1, L1, 1)

# Cahn–Hilliard
# Periodic domain, t in [0,20], constants = 1 (From Table I)
D  = 1.0
a2 = 1.0
a4 = 1.0
x0 = 0.0
L  = 128.0
xf = x0 + L
tfinal = 20.0

# Burgers
#L = 2
#x0 = -1
#xf = x0 + L
#tfinal = 1
#nu = 0.01 / np.pi


Nepochs_ADAM  = 1000
Nchange  = 500
Nint     = 8000
N0       = 500
Nb       = 500
Nprint   = 100

k1 = 1
k2 = 1
rad_args = (k1, k2)

# %%
class CustomActivation(nn.Module):
    def __init__(self, **kwargs):
        super().__init__()

    def forward(self, x):
        return x * scaling


def init_variance_scaling_fan_avg_uniform(linear, scale):
    fan_in, fan_out = linear.in_features, linear.out_features
    n = 0.5 * (fan_in + fan_out)
    limit = math.sqrt(3.0 * scale / n)
    with torch.no_grad():
        linear.weight.uniform_(-limit, limit)
        if linear.bias is not None:
            linear.bias.zero_()

class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(layer_dims[0], layer_dims[1]), nn.Tanh(),
            nn.Linear(layer_dims[1], layer_dims[2]), nn.Tanh(),
            nn.Linear(layer_dims[2], layer_dims[3]), nn.Tanh(),
            nn.Linear(layer_dims[3], layer_dims[4]), nn.Tanh(),
            nn.Linear(layer_dims[4], layer_dims[5]),
            CustomActivation(),)
        final_linear = self.net[-2]
        init_variance_scaling_fan_avg_uniform(final_linear, scale=1.0/(scaling**2))

    def forward(self, x):
        return self.net(x)

N = Net()

def generate_inputs(Nint):
    t = tfinal * np.random.rand(Nint)
    x = L * np.random.rand(Nint) + x0
    X = np.hstack((t[:, None], x[:, None]))
    return torch.as_tensor(X)

def initial_points(N0):
    t = np.zeros(N0)
    x = L * np.random.rand(N0) + x0
    X = np.hstack((t[:, None], x[:, None]))
    return torch.as_tensor(X)

# Changed boundary sampling
def boundary_points_periodic(Nb):
    t = tfinal * np.random.rand(Nb)
    Xl = np.hstack((t[:, None], (x0 * np.ones_like(t))[:, None]))
    Xr = np.hstack((t[:, None], (xf * np.ones_like(t))[:, None]))
    return torch.as_tensor(Xl), torch.as_tensor(Xr)

# def boundary_points(Nb):
#    t = tfinal * np.random.rand(Nb)
#    x = L * np.random.randint(0, 2, size=(Nb,)) + x0
#    X = np.hstack((t[:, None], x[:, None]))
#    return torch.as_tensor(X)

def generate_validation(Nt, Nx):
    x = np.linspace(x0, xf, Nx)
    t = np.linspace(0, tfinal, Nt)
    x, t = np.meshgrid(x, t)
    X = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))
    print('x', x.shape, 't', t.shape, 'X', X.shape)
    return torch.as_tensor(X), t, x

def adaptive_rad(N, Nint, rad_args, Nsampling=50000):
    Xtest = generate_inputs(Nsampling)
    k1, k2 = rad_args
    Y = torch.abs(get_results(N, Xtest)[-1]).reshape(-1)
    w = (Y**k1)
    err_eq = w / w.mean() + k2
    p = (err_eq / err_eq.sum()).clamp_min(1e-12)
    X_ids = torch.multinomial(p, num_samples=Nint, replacement=False)
    return Xtest[X_ids]

def uinit(X):
    x = X[:, 1:2]
    z = 2.0 * torch.pi * (x - x0) / L
    u0 = 0.0
    for k in range(1, K+1):
        u0 = u0 + ak[k-1] * torch.sin(k * z) + bk[k-1] * torch.cos(k * z)
    return torch.tanh(u0)

# def uinit(X):
#     x = X[:, 1:2]
#     return -torch.sin(torch.pi * x)

# def uleft(X):
#     Xleft = X[X[:, 1] == x0]
#     t = Xleft[:, 0]
#     return torch.zeros((t.shape[0], 1), dtype=torch.float64)

# def uright(X):
#     Xright = X[X[:, 1] == xf]
#     t = Xright[:, 0]
#     return torch.zeros((t.shape[0], 1), dtype=torch.float64)

def output(N, X):
    Nout = N(X)
    u = Nout[:, 0:1]
    return u

def get_results(N, X):
    X = X.clone().detach().requires_grad_(True)
    u = output(N, X)

    # first derivatives
    grads = torch.autograd.grad(
        u, X,
        grad_outputs=torch.ones_like(u),
        create_graph=True,
        retain_graph=True
    )[0]
    u_t = grads[:, 0:1]
    u_x = grads[:, 1:2]

    # second derivative u_xx
    u_xx = torch.autograd.grad(
        u_x, X,
        grad_outputs=torch.ones_like(u_x),
        create_graph=True,
        retain_graph=True
    )[0][:, 1:2]

    # chemical potential mu
    mu = u_xx + a2 * u + a4 * (u**3)

    # mu_x and mu_xx
    mu_x = torch.autograd.grad(
        mu, X,
        grad_outputs=torch.ones_like(mu),
        create_graph=True,
        retain_graph=True
    )[0][:, 1:2]

    mu_xx = torch.autograd.grad(
        mu_x, X,
        grad_outputs=torch.ones_like(mu_x),
        create_graph=True,
        retain_graph=True
    )[0][:, 1:2]

    fu = u_t - D * mu_xx
    return u, fu

# def get_results(N, X):
#     X.requires_grad_(True)
#     u = output(N, X)
#     grads = torch.autograd.grad(
#         u, X,
#         grad_outputs=torch.ones_like(u),
#         create_graph=True,
#         retain_graph=True)[0]
#     u_t = grads[:, 0]
#     u_x = grads[:, 1]

#     u_xx = torch.autograd.grad(
#         u_x, X,
#         grad_outputs=torch.ones_like(u_x),
#         create_graph=True,
#         retain_graph=True)[0][:, 1]
#     fu = u_t + u[:, 0] * u_x - nu * u_xx
#     return u, fu

# New helper to computer u_x at boundary points
def ux_of(N, X):
    X = X.clone().detach().requires_grad_(True)
    u = output(N, X)
    grads = torch.autograd.grad(
        u, X,
        grad_outputs=torch.ones_like(u),
        create_graph=True,
        retain_graph=True
    )[0]
    return grads[:, 1:2]


loss_function = nn.MSELoss()

lam0 = 5.0     # IC weight
lamP = 5.0     # periodic BC weight

def loss(fu, u0, u0pinn, ul, ur, uxl, uxr):
    zeros = torch.zeros_like(fu)
    return (
        loss_function(fu, zeros)
        + lam0 * loss_function(u0pinn, u0)
        + lamP * (loss_function(ul, ur) + loss_function(uxl, uxr))
    )

# lam0 = 5.0
# lamB = 5.0

# def loss(fu, u0, u0pinn, ul, ulpinn, ur, urpinn):
#     Ntot = fu.shape[0]
#     zeros = torch.zeros((Ntot, 1), dtype=torch.get_default_dtype(), device=fu.device)
#     fu_col = fu.reshape(-1, 1)
#     loss_value = (loss_function(fu_col, zeros)
#                   + lam0 * loss_function(u0, u0pinn)
#                   + lamB * (loss_function(ul, ulpinn) + loss_function(ur, urpinn)))
#     return loss_value

def grads(N, X, X0, Xbl, Xbr):
    for p in N.parameters():
        p.grad = None

    # interior residual
    _, fu = get_results(N, X)

    # initial condition at t=0
    u0 = uinit(X0)
    u0pinn = output(N, X0)

    # periodic boundary constraints
    ul = output(N, Xbl)
    ur = output(N, Xbr)
    uxl = ux_of(N, Xbl)
    uxr = ux_of(N, Xbr)

    loss_value = loss(fu, u0, u0pinn, ul, ur, uxl, uxr)
    loss_value.backward()
    gradsN = [p.grad for p in N.parameters()]
    return gradsN, loss_value

# def grads(N, X, X0, Xb):
#     for p in N.parameters():
#         p.grad = None

#     X = X.clone().detach().requires_grad_(True)
#     X0 = X0.clone().detach().requires_grad_(True)
#     _, fu = get_results(N, X)
#     u0 = uinit(X0)
#     u0pinn = output(N, X0)
#     ul = uleft(Xb)
#     ur = uright(Xb)
#     mask_l = (Xb[:, 1] == x0)
#     mask_r = (Xb[:, 1] == xf)
#     ulpinn = output(N, Xb[mask_l])
#     urpinn = output(N, Xb[mask_r])

#     loss_value = loss(fu, u0, u0pinn, ul, ulpinn, ur, urpinn)

#     loss_value.backward()

#     gradsN = [p.grad for p in N.parameters()]
#     return gradsN, loss_value

def training(N, X, X0, Xbl, Xbr, optimizer):
    _, loss_value = grads(N, X, X0, Xbl, Xbr)
    optimizer.step()
    return loss_value

# def training(N, X, X0, Xb, optimizer):
#     _, loss_value = grads(N, X, X0, Xb)
#     optimizer.step()
#     return loss_value


X  = generate_inputs(Nint)
X0 = initial_points(N0)
Xbl, Xbr = boundary_points_periodic(Nb)
# Xb = boundary_points(Nb)


mat = scipy.io.loadmat("burgers_canonical.mat")
u_ref  = mat["usol"]
t_star = mat["t"].ravel()
x_star = mat["x"].ravel()
x_star, t_star = np.meshgrid(x_star, t_star)

device = next(N.parameters()).device
X_star = torch.as_tensor(
    np.hstack((t_star.reshape(-1,1), x_star.reshape(-1,1))),
    dtype=torch.get_default_dtype(),
    device=device)
template = 'Epoch {}, loss: {}'

rel_adam = []
optimizer = torch.optim.Adam(N.parameters(), lr=5e-3, betas=(0.99, 0.999), eps=1e-20)
adam_scheduler = torch.optim.lr_scheduler.LambdaLR(
    optimizer, lr_lambda=lambda step: 0.98 ** (step / 1000.0))

adam_losses = []
start_time = perf_counter()

adam_t0 = perf_counter()
for epoch in range(Nepochs_ADAM):
    if (epoch + 1) % Nchange == 0:
        X  = adaptive_rad(N, Nint, rad_args)
        # X0 = initial_points(N0)
        Xbl, Xbr = boundary_points_periodic(Nb)
        # Xb = boundary_points(Nb)

    loss_value = training(N, X, X0, Xbl, Xbr, optimizer)
    adam_losses.append(float(loss_value.detach().cpu().item()))

    if (epoch + 1) % Nprint == 0:
        print(template.format(epoch + 1, adam_losses[-1]))

        # N.eval()
        # with torch.no_grad():
        #     u_pred = output(N, X_star).detach().cpu().numpy().reshape(u_ref.shape)
        # N.train()

        # num = np.linalg.norm(u_ref - u_pred)
        # den = np.linalg.norm(u_pred) + 1e-12
        # rel = num / den
        # rel_adam.append((epoch + 1, float(rel)))


adam_time_sec = perf_counter() - adam_t0

def nested_tensor(grad, layer_dims, train_activations=False, bias=True):
    _has_torch = True
    if _has_torch and isinstance(grad, torch.Tensor):
        grad = grad.detach().cpu().numpy()
    grad = np.asarray(grad).ravel()

    if not train_activations:
        if bias:
            temp = [None] * (2 * len(layer_dims) - 2)
        else:
            temp = [None] * (2 * len(layer_dims) - 3)

        index = 0
        for i in range(len(temp)):
            if i % 2 == 0:
                k = i // 2
                fan_in, fan_out = layer_dims[k], layer_dims[k + 1]
                expected_shape = (fan_in, fan_out)
                size = fan_in * fan_out

                print('layer_dims', layer_dims)
                print(f"Expected shape: {expected_shape}, Grad slice size: {size}")
                print(f"Current index: {index}, Next index: {index + size}")
                print(f"Size of grad slice: {grad[index:index+size].size}")

                temp[i] = grad[index:index + size].reshape(expected_shape)
                index += size
            else:
                k = i - (i // 2)
                bsz = layer_dims[k]
                temp[i] = grad[index:index + bsz]
                index += bsz
        return temp

    else:
        temp = [None] * (3 * len(layer_dims) - 4)
        index = 0
        for i in range(len(temp)):
            if i % 3 == 0:

                k = i // 3
                fan_in, fan_out = layer_dims[k], layer_dims[k + 1]
                size = fan_in * fan_out
                temp[i] = grad[index:index + size].reshape(fan_in, fan_out)
                index += size
            elif i % 3 == 1:

                k = int((i + 2) / 3)
                bsz = layer_dims[k]
                temp[i] = grad[index:index + bsz]
                index += bsz
            else:

                temp[i] = grad[index]
                index += 1
        return temp


power = 1.0

def loss_and_gradient_torch(N, X, X0, Xbl, Xbr, power=power):
    X = X.clone().detach().requires_grad_(True)

    _, fu = get_results(N, X)

    # IC
    u0 = uinit(X0)
    u0pinn = output(N, X0)

    # periodic BCs
    ul = output(N, Xbl)
    ur = output(N, Xbr)
    uxl = ux_of(N, Xbl)
    uxr = ux_of(N, Xbr)

    loss_value = loss(fu, u0, u0pinn, ul, ur, uxl, uxr)
    loss_root = loss_value if power == 1.0 else loss_value ** (1.0 / power)

    params = list(N.parameters())
    gradsN = torch.autograd.grad(loss_root, params, create_graph=False)
    return loss_root, gradsN

# def loss_and_gradient_torch(N, X, X0, Xbl, Xbr, power=power):
#     X = X.clone().detach().requires_grad_(True)
#     _, fu = get_results(N, X)
#     u0 = uinit(X0)
#     u0pinn = output(N, X0)
#     ul = uleft(Xb)
#     mask_l = (Xb[:, 1] == x0)
#     ulpinn = output(N, Xb[mask_l])
#     ur = uright(Xb)
#     mask_r = (Xb[:, 1] == xf)
#     urpinn = output(N, Xb[mask_r])
#     loss_value = loss(fu, u0, u0pinn, ul, ulpinn, ur, urpinn)
#     loss_root = loss_value if power == 1.0 else loss_value ** (1.0 / power)
#     params = list(N.parameters())
#     gradsN = torch.autograd.grad(
#         loss_root, params,
#         create_graph=False, retain_graph=False, allow_unused=False)
#     return loss_root, gradsN


def loss_and_gradient(weights, N, X, X0, Xbl, Xbr, layer_dims=None):
    first_param = next(N.parameters())
    device = first_param.device
    dtype = first_param.dtype

    w_tensor = torch.as_tensor(weights, dtype=dtype, device=device)
    with torch.no_grad():
        vector_to_parameters(w_tensor, N.parameters())

    loss_val, grads_list = loss_and_gradient_torch(N, X, X0, Xbl, Xbr, power=power)
    grads_flat = torch.cat([g.reshape(-1) for g in grads_list])

    return float(loss_val.detach().cpu().item()), grads_flat.detach().cpu().numpy()

# def loss_and_gradient(weights, N, X, X0, Xb, layer_dims=None):
#     first_param = next(N.parameters())
#     device = first_param.device
#     dtype = first_param.dtype
#     w_tensor = torch.as_tensor(weights, dtype=dtype, device=device)

#     with torch.no_grad():
#         vector_to_parameters(w_tensor, N.parameters())
#     loss_val, grads_list = loss_and_gradient_torch(N, X, X0, Xb, power=power)
#     grads_flat = torch.cat([g.reshape(-1) for g in grads_list])

#     return float(loss_val.detach().cpu().item()), grads_flat.detach().cpu().numpy()


Nbfgs = 10000
Nbatches = int(round(Nbfgs / Nchange))
Nprint = 100
n_ckpts        = Nbfgs // Nprint
warmup_steps   = len(adam_losses)
epochs_bfgs    = warmup_steps + np.arange(1, n_ckpts + 1, dtype=float) * Nprint
lossbfgs        = np.zeros(n_ckpts, dtype=float)
validation_list = np.zeros(n_ckpts, dtype=float)
error_list      = np.zeros(n_ckpts, dtype=float)
time_elapsed = np.array([])
initial_time = perf_counter()

Nt = 300
Nx = 300
Xtest, t, x = generate_validation(Nt, Nx)
X0test = Xtest[:Nx]
mask_b = (Xtest[:, 1] == x0) | (Xtest[:, 1] == xf)
Xbtest = Xtest[mask_b]


initial_weights = parameters_to_vector([p.detach() for p in N.parameters()]).cpu().numpy()

cont = 0
def callback(*, intermediate_result):
    global N, cont, lossbfgs, Nprint, u_ref, \
           x_star, X_star, Xtest, validation_list, X0test, Xbtest, error_list, power

    device = next(N.parameters()).device
    dtype  = next(N.parameters()).dtype

    cont += 1
    if (cont % Nprint) != 0:
        return

    idx = cont // Nprint - 1
    if idx < 0 or idx >= len(lossbfgs):  # guard
        return

    loss_value = float((intermediate_result.fun) ** power)
    lossbfgs[idx] = loss_value

    _, futest = get_results(N, Xtest.to(device))
    zeros = torch.zeros((futest.shape[0], 1), dtype=dtype, device=device)

    with torch.no_grad():
        u_pred = output(N, X_star).reshape(x_star.shape)
        u_ref_t = torch.as_tensor(u_ref, dtype=dtype, device=device)
        v1 = loss_function(u_pred, u_ref_t)
        v2 = loss_function(futest.reshape(-1,1), zeros)
        validation_list[idx] = (v1 + v2).item()

    u_np = u_pred.detach().cpu().numpy()
    num = np.linalg.norm(u_ref - u_np)
    den = np.linalg.norm(u_np) + 1e-12
    error_list[idx] = num / den

    print(f"Iteration {cont} (ckpt {idx+1}/{len(lossbfgs)}): "
          f"Train {loss_value:.3e}, relL2 {error_list[idx]:.3e}")


method = "BFGS"
method_bfgs = "SSBroyden2"
initial_scale = False
warmup_tag = "warmup_adam"

os.makedirs("results2", exist_ok=True)

def _scipy_cb_factory():
    class _Res:
        __slots__ = ("fun",)
        def __init__(self, fun): self.fun = fun
    def _cb(xk):
        f, _ = loss_and_gradient(xk, N, X, X0, Xbl, Xbr, layer_dims)
        callback(intermediate_result=_Res(f))
    return _cb

H0 = np.eye(initial_weights.size, dtype=np.float64)

initial_time_bfgs = perf_counter()

bfgs_loss_ckpt = []
bfgs_rel       = []

bfgs_t0 = perf_counter()

while cont < Nbfgs:
    print(cont)
    result = minimize(
        loss_and_gradient,
        initial_weights,
        args=(N, X, X0, Xbl, Xbr, layer_dims),
        # args=(N, X, X0, Xb, layer_dims),
        method=method,
        jac=True,
        options={
            'maxiter': Nchange,
            'gtol': 0,
            'hess_inv0': H0,
            'method_bfgs': method_bfgs,
            'initial_scale': initial_scale },
        tol=0,
        callback=callback)

    initial_weights = result.x
    H0 = result.hess_inv
    H0 = 0.5 * (H0 + H0.T)

    try:
        cholesky(H0)
    except LinAlgError:
        H0 = np.eye(len(initial_weights), dtype=np.float64)



    # X  = adaptive_rad(N, Nint, rad_args)
    # X0 = initial_points(N0)
    # Xbl, Xbr = boundary_points_periodic(Nb)
    # # Xb = boundary_points(Nb)
    # _, fu   = get_results(N, X)
    # u0      = uinit(X0)
    # u0pinn  = output(N, X0)
    # ul      = uleft(Xb)
    # ulpinn  = output(N, Xb[Xb[:, 1] == x0])
    # ur      = uright(Xb)
    # urpinn  = output(N, Xb[Xb[:, 1] == xf])
    # loss_value = loss(fu, u0, u0pinn, ul, ulpinn, ur, urpinn)

    X  = adaptive_rad(N, Nint, rad_args)
    # keep X0 fixed if you want consistent IC enforcement
    Xbl, Xbr = boundary_points_periodic(Nb)
    _, loss_value = grads(N, X, X0, Xbl, Xbr)
    print("post-bfgs chunk loss:", float(loss_value.detach().cpu()))

    # (optional) compute current loss for logging/debug
    with torch.no_grad():
        pass  # you can log if you want, but don't call uleft/uright anymore

    initial_scale = False

bfgs_time_sec = perf_counter() - bfgs_t0
# Out:
# Epoch 100, loss: 0.4013274349779131
# Epoch 200, loss: 0.374028899027572
# Epoch 300, loss: 0.3385326067729505
# Epoch 400, loss: 0.2970582583153358
# Epoch 500, loss: 0.27181886822770834
# Epoch 600, loss: 0.2660655525199278
# Epoch 700, loss: 0.26279102648704583
# Epoch 800, loss: 0.2601803506294692
# Epoch 900, loss: 0.2545188191736363
# Epoch 1000, loss: 0.2517989946445109
# x (300, 300) t (300, 300) X (90000, 2)
# 0
# /tmp/ipython-input-37813/1188900750.py:533: OptimizeWarning: Unknown solver options: method_bfgs, initial_scale
#   result = minimize(
# Iteration 100 (ckpt 1/100): Train 2.308e-01, relL2 2.271e+00
# Iteration 200 (ckpt 2/100): Train 1.840e-01, relL2 2.324e+00
# Iteration 300 (ckpt 3/100): Train 1.627e-01, relL2 1.786e+00
# Iteration 400 (ckpt 4/100): Train 8.734e-02, relL2 1.861e+00
# Iteration 500 (ckpt 5/100): Train 1.382e-03, relL2 1.703e+00
# post-bfgs chunk loss: 0.0020902178967515507
# 500
# Iteration 600 (ckpt 6/100): Train 5.402e-04, relL2 1.767e+00
# Iteration 700 (ckpt 7/100): Train 2.055e-04, relL2 1.752e+00
# Iteration 800 (ckpt 8/100): Train 1.354e-04, relL2 1.761e+00
# Iteration 900 (ckpt 9/100): Train 1.031e-04, relL2 1.799e+00
# Iteration 1000 (ckpt 10/100): Train 7.832e-05, relL2 1.821e+00
# post-bfgs chunk loss: 0.00016457205588408301
# 1000
# Iteration 1100 (ckpt 11/100): Train 1.038e-04, relL2 1.798e+00
# Iteration 1200 (ckpt 12/100): Train 8.346e-05, relL2 1.797e+00
# Iteration 1300 (ckpt 13/100): Train 7.033e-05, relL2 1.789e+00
# Iteration 1400 (ckpt 14/100): Train 6.063e-05, relL2 1.785e+00
# Iteration 1500 (ckpt 15/100): Train 5.373e-05, relL2 1.780e+00
# post-bfgs chunk loss: 7.28610667512671e-05
# 1500
# Iteration 1600 (ckpt 16/100): Train 5.750e-05, relL2 1.770e+00
# Iteration 1700 (ckpt 17/100): Train 4.901e-05, relL2 1.765e+00
# Iteration 1800 (ckpt 18/100): Train 4.396e-05, relL2 1.768e+00
# Iteration 1900 (ckpt 19/100): Train 4.143e-05, relL2 1.771e+00
# Iteration 2000 (ckpt 20/100): Train 3.939e-05, relL2 1.772e+00
# post-bfgs chunk loss: 5.3852657791753635e-05
# 2000
# Iteration 2100 (ckpt 21/100): Train 4.538e-05, relL2 1.779e+00
# Iteration 2200 (ckpt 22/100): Train 4.326e-05, relL2 1.771e+00
# Iteration 2300 (ckpt 23/100): Train 4.143e-05, relL2 1.757e+00
# Iteration 2400 (ckpt 24/100): Train 4.003e-05, relL2 1.754e+00
# Iteration 2500 (ckpt 25/100): Train 3.837e-05, relL2 1.754e+00
# post-bfgs chunk loss: 4.585276747820679e-05
# 2500
# Iteration 2600 (ckpt 26/100): Train 4.012e-05, relL2 1.757e+00
# Iteration 2700 (ckpt 27/100): Train 3.836e-05, relL2 1.758e+00
# Iteration 2800 (ckpt 28/100): Train 3.686e-05, relL2 1.760e+00
# Iteration 2900 (ckpt 29/100): Train 3.586e-05, relL2 1.765e+00
# Iteration 3000 (ckpt 30/100): Train 3.482e-05, relL2 1.765e+00
# post-bfgs chunk loss: 3.796907220428482e-05
# 3000
# Iteration 3100 (ckpt 31/100): Train 3.419e-05, relL2 1.761e+00
# Iteration 3200 (ckpt 32/100): Train 3.299e-05, relL2 1.752e+00
# Iteration 3300 (ckpt 33/100): Train 3.234e-05, relL2 1.752e+00
# Iteration 3400 (ckpt 34/100): Train 3.151e-05, relL2 1.748e+00
# Iteration 3500 (ckpt 35/100): Train 3.064e-05, relL2 1.749e+00
# post-bfgs chunk loss: 3.643782613456256e-05
# 3500
# Iteration 3600 (ckpt 36/100): Train 3.393e-05, relL2 1.758e+00
# Iteration 3700 (ckpt 37/100): Train 3.299e-05, relL2 1.756e+00
# Iteration 3800 (ckpt 38/100): Train 3.235e-05, relL2 1.753e+00
# Iteration 3900 (ckpt 39/100): Train 3.167e-05, relL2 1.751e+00
# Iteration 4000 (ckpt 40/100): Train 3.096e-05, relL2 1.754e+00
# post-bfgs chunk loss: 3.498426547719563e-05
# 4000
# Iteration 4100 (ckpt 41/100): Train 3.264e-05, relL2 1.748e+00
# Iteration 4200 (ckpt 42/100): Train 3.191e-05, relL2 1.749e+00
# Iteration 4300 (ckpt 43/100): Train 3.121e-05, relL2 1.753e+00
# Iteration 4400 (ckpt 44/100): Train 3.046e-05, relL2 1.750e+00
# Iteration 4500 (ckpt 45/100): Train 2.978e-05, relL2 1.752e+00
# post-bfgs chunk loss: 3.478923848310808e-05
# 4500
# Iteration 4600 (ckpt 46/100): Train 3.246e-05, relL2 1.757e+00
# Iteration 4700 (ckpt 47/100): Train 3.187e-05, relL2 1.756e+00
# Iteration 4800 (ckpt 48/100): Train 3.120e-05, relL2 1.755e+00
# Iteration 4900 (ckpt 49/100): Train 3.053e-05, relL2 1.756e+00
# Iteration 5000 (ckpt 50/100): Train 3.009e-05, relL2 1.758e+00
# post-bfgs chunk loss: 3.269941839837125e-05
# 5000
# Iteration 5100 (ckpt 51/100): Train 3.033e-05, relL2 1.755e+00
# Iteration 5200 (ckpt 52/100): Train 2.988e-05, relL2 1.751e+00
# Iteration 5300 (ckpt 53/100): Train 2.935e-05, relL2 1.751e+00
# Iteration 5400 (ckpt 54/100): Train 2.893e-05, relL2 1.752e+00
# Iteration 5500 (ckpt 55/100): Train 2.846e-05, relL2 1.752e+00
# post-bfgs chunk loss: 3.1221621257109225e-05
# 5500
# Iteration 5600 (ckpt 56/100): Train 2.959e-05, relL2 1.749e+00
# Iteration 5700 (ckpt 57/100): Train 2.914e-05, relL2 1.745e+00
# Iteration 5800 (ckpt 58/100): Train 2.881e-05, relL2 1.741e+00
# Iteration 5900 (ckpt 59/100): Train 2.847e-05, relL2 1.742e+00
# Iteration 6000 (ckpt 60/100): Train 2.818e-05, relL2 1.741e+00
# post-bfgs chunk loss: 2.8378016115490695e-05
# 6000
# Iteration 6100 (ckpt 61/100): Train 2.572e-05, relL2 1.752e+00
# Iteration 6200 (ckpt 62/100): Train 2.537e-05, relL2 1.753e+00
# Iteration 6300 (ckpt 63/100): Train 2.502e-05, relL2 1.751e+00
# Iteration 6400 (ckpt 64/100): Train 2.472e-05, relL2 1.750e+00
# Iteration 6500 (ckpt 65/100): Train 2.456e-05, relL2 1.751e+00
# post-bfgs chunk loss: 2.9800913766297866e-05
# 6500
# Iteration 6600 (ckpt 66/100): Train 2.703e-05, relL2 1.746e+00
# Iteration 6700 (ckpt 67/100): Train 2.678e-05, relL2 1.743e+00
# Iteration 6800 (ckpt 68/100): Train 2.648e-05, relL2 1.741e+00
# Iteration 6900 (ckpt 69/100): Train 2.605e-05, relL2 1.739e+00
# Iteration 7000 (ckpt 70/100): Train 2.580e-05, relL2 1.737e+00
# post-bfgs chunk loss: 2.911735793557661e-05
# 7000
# Iteration 7100 (ckpt 71/100): Train 2.715e-05, relL2 1.744e+00
# Iteration 7200 (ckpt 72/100): Train 2.665e-05, relL2 1.748e+00
# Iteration 7300 (ckpt 73/100): Train 2.640e-05, relL2 1.748e+00
# Iteration 7400 (ckpt 74/100): Train 2.608e-05, relL2 1.746e+00
# Iteration 7500 (ckpt 75/100): Train 2.581e-05, relL2 1.746e+00
# post-bfgs chunk loss: 2.7236834999377613e-05
# 7500
# Iteration 7600 (ckpt 76/100): Train 2.534e-05, relL2 1.740e+00
# Iteration 7700 (ckpt 77/100): Train 2.500e-05, relL2 1.741e+00
# Iteration 7800 (ckpt 78/100): Train 2.468e-05, relL2 1.740e+00
# Iteration 7900 (ckpt 79/100): Train 2.443e-05, relL2 1.740e+00
# Iteration 8000 (ckpt 80/100): Train 2.410e-05, relL2 1.744e+00
# post-bfgs chunk loss: 2.8280752170855274e-05
# 8000
# Iteration 8100 (ckpt 81/100): Train 2.654e-05, relL2 1.748e+00
# Iteration 8200 (ckpt 82/100): Train 2.616e-05, relL2 1.750e+00
# Iteration 8300 (ckpt 83/100): Train 2.582e-05, relL2 1.750e+00
# Iteration 8400 (ckpt 84/100): Train 2.555e-05, relL2 1.749e+00
# Iteration 8500 (ckpt 85/100): Train 2.536e-05, relL2 1.751e+00
# post-bfgs chunk loss: 2.6020051909455563e-05
# 8500
# Iteration 8600 (ckpt 86/100): Train 2.379e-05, relL2 1.743e+00
# Iteration 8700 (ckpt 87/100): Train 2.352e-05, relL2 1.738e+00
# Iteration 8800 (ckpt 88/100): Train 2.332e-05, relL2 1.739e+00
# Iteration 8900 (ckpt 89/100): Train 2.317e-05, relL2 1.741e+00
# Iteration 9000 (ckpt 90/100): Train 2.298e-05, relL2 1.738e+00
# post-bfgs chunk loss: 2.667656843131918e-05
# 9000
# Iteration 9100 (ckpt 91/100): Train 2.444e-05, relL2 1.746e+00
# Iteration 9200 (ckpt 92/100): Train 2.413e-05, relL2 1.742e+00
# Iteration 9300 (ckpt 93/100): Train 2.396e-05, relL2 1.742e+00
# Iteration 9400 (ckpt 94/100): Train 2.369e-05, relL2 1.741e+00
# Iteration 9500 (ckpt 95/100): Train 2.343e-05, relL2 1.741e+00
# post-bfgs chunk loss: 2.4222640419475832e-05
# 9500
# Iteration 9600 (ckpt 96/100): Train 2.290e-05, relL2 1.745e+00
# Iteration 9700 (ckpt 97/100): Train 2.255e-05, relL2 1.749e+00
# Iteration 9800 (ckpt 98/100): Train 2.230e-05, relL2 1.749e+00
# Iteration 9900 (ckpt 99/100): Train 2.193e-05, relL2 1.747e+00
# Iteration 10000 (ckpt 100/100): Train 2.166e-05, relL2 1.747e+00
# post-bfgs chunk loss: 2.4863159117067035e-05
